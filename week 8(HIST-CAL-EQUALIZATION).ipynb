# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img_path="C:\\Users\\anura\\OneDrive\\Desktop\\download.jpeg"
img=cv2.imread(img_path,0)
equalize=cv2.equalizeHist(img)
res=np.hstack((img,equalize))
histogram_plot=cv2.calcHist([img],[0],None,[255],[0,256])
plt.imshow(res)
plt.show()
plt.plot(histogram_plot)
plt.show()
